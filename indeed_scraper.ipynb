# %%
# imports
from bs4 import BeautifulSoup
import pandas as pd
from time import sleep
from datetime import date
import requests
import undetected_chromedriver as uc
import urllib.parse

# %%
headers = {
  "User-agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.120 Safari/537.36"}

res = requests.get('https://www.indeed.com/jobs?q=software+developer', headers=headers) 
print(dir(res))
# Out:
# ['__attrs__', '__bool__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__nonzero__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_content', '_content_consumed', '_next', 'apparent_encoding', 'close', 'connection', 'content', 'cookies', 'elapsed', 'encoding', 'headers', 'history', 'is_permanent_redirect', 'is_redirect', 'iter_content', 'iter_lines', 'json', 'links', 'next', 'ok', 'raise_for_status', 'raw', 'reason', 'request', 'status_code', 'text', 'url']

# %%
url = "https://www.indeed.com/jobs?q=software+developer"

payload = ""
headers = {
  'Authorization': 'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpYXQiOjE2NzM5OTgxMTcsImV4cCI6MTY3NDAwMTcxN30.C10qRQLvWgMFOWfwrW9hECIP44LrQmOR8WzR-3ghQH4',
  'Cookie': 'CTK=1gpu892pik7i9800; __cf_bm=9Qu_iWGF_hZ6VonV17zH1yBoUukIiJq52af7QM3N10o-1677126307-0-Aahwo58ATVUH9lHIV7CJcAERJfj5QQqpUP2vi2DciCDNhS3CTpHKLD/fAD+nqOFuWsA0equKTzvgXIKYi5RZ1qk=; _cfuvid=Z.9vfYhwVv_olyH0i.YuaXeRGTMv4VpLSbCarlBL6gI-1677126307162-0-604800000; INDEED_CSRF_TOKEN=tBGpXDlM1aB4t1tgoOMDYPO4SHoCdCSA; JSESSIONID=EB076B46C74DFB4AC27A1BD433DBB939; LV="LA=1677126306:CV=1677126306:TS=1677126306"; RQ="q=software+developer&l=&ts=1677126366336"; UD="LA=1677126366:CV=1677126306:TS=1677126306:SG=945c41d3bb6cfc369fbd8e6112303114"; indeed_rcc="LV:CTK:UD"; jaSerpCount=2; loctip=1'
}

response = requests.request("GET", url, headers=headers, data=payload)
print(response)
# Out:
# <Response [403]>

# %%
base = "https://www.indeed.com/jobs?"
params = {}
params['q'] = 'software developer'
search= base + urllib.parse.urlencode(params)
search
# Out:
# 'https://www.indeed.com/jobs?q=software+developer'

# %%
# web driver setup
driver = uc.Chrome()

# %%
# get first page
driver.get('https://www.indeed.com/jobs?q=software+developer')
sleep(5)
html = driver.page_source

# %%
# Making soup
soup = BeautifulSoup(html, 'html.parser')

# %%
# Create dataframe
df = pd.DataFrame()

# %%
# parent container for job cards
jobs_list=soup.find('div', attrs={'id': 'mosaic-provider-jobcards'})

# extracting data from each job card
titles = [title.text for title in jobs_list.find_all('h2', class_='jobTitle')] 
df['Job_Title'] = titles

companies = [company.text for company in jobs_list.find_all('span',class_='companyName') ]
df['Company'] = companies

links = [link['href'] for link in jobs_list.find_all('a', class_='jcs-JobTitle') ]
df['Link'] = links

# %%
# sample url to job listing 
url = 'https://indeed.com' + links[0]
print(url)
# Out:
# https://indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0DU7nQRDbH4s4aLIJcXdF8O4sVsxvpk95xASanc1ljvNfDwck7v1oMuW4XFjsKUcpnzfeEFKqo493ivVBZ4WXQc1yK2sD5OfL32Y18G0Ysk2gkH7d0MMPXOwGDVHvTTUDkjjKUdJNWxfYp9QwrS-fF5M9lVU0qlmkuU78gQAeVeuB7ca_03OEczABrNBPkVoJ2O8TM_lfn672sQTWeRnmcWjqzgZDM3nfbcyCgqpFt6mmJFKDCG_m786hmthjyPRYL1YWUz8PG0UGlSKDlbPb560zgdbyPdnCcWLoh-6R2wSL8ApmWTeBvJi-NWYZPMGiyINPy039ocBbEpS5rZDusqcAzd7KKvFai7BBBvwAfqf_jgSIJNmkGcI3VuZMVpQTYqeeA5CsHKMbBCGs5BxJLdUYu-piLwo2zMMqMvx8NayodpkF0u9ZioQB62v6ZUftMlz_lLlrfuyzyYOEMbrbbdgaYFcGMfski3KBy0R0Ryp4jNXIJIi57jzu61oJEr2AOKUFm1ynpOWkWI3-kzlOrGlZqdkDAjSlZU76jaDMBbFaBw9aqhjaUYyAG2E5w8tUx2GobZznb1_s2ETCLRd7QdGAeuezvF_UU=&xkcb=SoAu-_M3SNHup4WaCh0JbzkdCdPP&p=0&fvj=0&vjs=3

# %%
df
# Out:
#                                             Job_Title  \
# 0                          Senior Site Core Developer
# 1                           TJA Application Developer
# 2                                   Shopify Developer
# 3                                 Computer Programmer
# 4            Staff Software Engineer, Personalization
# 5          Full Stack Developer | Design | Blockchain
# 6                          Software Engineer - Remote
# 7                                Full Stack Developer
# 8   Software Control Engineer (RELOCATION ASSISTAN...
# 9                   Software Engineer, Infrastructure
# 10               Software Engineer I (Remote Option*)
# 11                       Software Developer - Digital
# 12  Software Engineer I - Production Support (Remote)
# 13                              Mid Software Engineer
# 14                Software Quality Assurance Engineer
#
#                            Company  \
# 0          Arrow Electronics, Inc.
# ...

# %%
# going to each job listing to get description
descriptions = []

for link in links:
    url = 'https://indeed.com' + link
    try:
        driver.get(url)
        sleep(5)
    except:
        descriptions.append('')
        continue
    html = driver.page_source
    cup = BeautifulSoup(html, 'html.parser')
    description = cup.find('div', id='jobDescriptionText')
    descriptions.append(description.text)

# %%
df['Description'] = descriptions

# %%
# 
df.Link = df.Link.apply(lambda link: 'https://indeed.com' + link)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Job_Title    15 non-null     object
#  1   Company      15 non-null     object
#  2   Link         15 non-null     object
#  3   Description  15 non-null     object
# dtypes: object(4)
# memory usage: 612.0+ bytes

# %%
df
# Out:
#                                             Job_Title  \
# 0                          Senior Site Core Developer
# 1                           TJA Application Developer
# 2                                   Shopify Developer
# 3                                 Computer Programmer
# 4            Staff Software Engineer, Personalization
# 5          Full Stack Developer | Design | Blockchain
# 6                          Software Engineer - Remote
# 7                                Full Stack Developer
# 8   Software Control Engineer (RELOCATION ASSISTAN...
# 9                   Software Engineer, Infrastructure
# 10               Software Engineer I (Remote Option*)
# 11                       Software Developer - Digital
# 12  Software Engineer I - Production Support (Remote)
# 13                              Mid Software Engineer
# 14                Software Quality Assurance Engineer
#
#                            Company  \
# 0          Arrow Electronics, Inc.
# ...

# %%
# Output
df.to_csv(f'indeed_{date.today()}.csv')
df.to_json(f'indeed_{date.today()}.json')
