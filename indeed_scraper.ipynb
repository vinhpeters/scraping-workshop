# %%
# imports
from bs4 import BeautifulSoup
import pandas as pd
from time import sleep
from datetime import date
import requests
import undetected_chromedriver as uc

# %%
headers = {
  "User-agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.120 Safari/537.36"}

res = requests.get('https://www.indeed.com/jobs?q=software+developer', headers=headers) 
print(res)
print(res.text)
# Out:
# <Response [403]>
# <!DOCTYPE html>
# <html lang="en-US">
# <head>
#     <title>Just a moment...</title>
#     <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=Edge">
#     <meta name="robots" content="noindex,nofollow">
#     <meta name="viewport" content="width=device-width,initial-scale=1">
#     <link href="/cdn-cgi/styles/challenges.css" rel="stylesheet">
#
#
# </head>
# <body class="no-js">
#     <div class="main-wrapper" role="main">
#     <div class="main-content">
#         <h1 class="zone-name-title h1">
#             <img class="heading-favicon" src="/favicon.ico" alt="Icon for www.indeed.com"
#                  onerror="this.onerror=null;this.parentNode.removeChild(this)">
#             www.indeed.com
#         </h1>
#         <h2 class="h2" id="challenge-running">
#             Checking if the site connection is secure
#         </h2>
#         <noscript>
#             <div id="challenge-error-title">
#                 <div class="h2">
#                     <span class="icon-wrapper">
#                         <div class="heading-icon warning-icon"></div>
#                     </span>
#                     <span id="challenge-error-text">
#                         Enable JavaScript and cookies to continue
#                     </span>
#                 </div>
#             </div>
#         </noscript>
#         <div id="trk_jschal_js" style="display:none;background-image:url('/cdn-cgi/images/trace/managed/nojs/transparent.gif?ray=79dd58628dd5397f')"></div>
#         <div id="challenge-body-text" class="core-msg spacer">
#             www.indeed.com needs to review the security of your connection before proceeding.
#         </div>
#         <form id="challenge-form" action="/jobs?q=software+developer&amp;__cf_chl_f_tk=8FGiHCvh0GQzAuHTKRLfQR.eHC9WVI2ptzpHezBV5W4-1677127874-0-gaNycGzNCVA" method="POST" enctype="application/x-www-form-urlencoded">
#             <input type="hidden" name="md" value="vAQKM6mFllUQn3jsiunVPrONqc_d0U7koz.ky4QvKb8-1677127874-0-AfEZ_9b2k2ieLF6pekGVUWG5dCnzeNkHCxsC6CEeCYZVY-6YRgmSzB7ld4w56yphiZfeE-kms45sHAKVEVSInJE71M7j92A22HmMfOCybI1u-gM6VIU5wfMZqMPxRAQwBi3fBwPnHqT8ospz6i4-8qY5MIuszytkuIwLJ2l6euK5elGLbyBOhppy0XPXIfSohIn1y1zYH4LsR2gJbKR5ZyFBqXMDwm6T5TNPsuYMsCO0VPTSL1uzsYusHBEEt5C5ZFFAFaCE2FsrD-winZFWKXyD3SjCpoAmWZM_lG-gD6KQ0hNXJilV59nTtkle9jlUC-qdlNWs8f4CCDkWAGmdrRp-aAR-f53T43LhfDwNmSt0jl3RfRWY9_JeZ6y4pEqhTiWQl7GwsoA66qAgOxWOmiV0Mho2bTPPsN27FtpXicgV2FHfs3sMH38BedIAnplY7RJ7e_gpTGitmVbRtd1Tb8Wv8PHVmxoqU7QAwu7kjE_FE5gIPZ6U6m3ODCCpRoMEeSy-TS-eIspqPkoakA1OMvSaiQWbcp8UQsSf-mZgzvBAltaWoBY0fRnXD-V1AEuhIwuyss6E1RJ1wpuAAp0hmkprLTIBszW_9A_Im5taNzn5XpBxTAC7q3sOJoul6KDZMyOUMpwSLkPYDfeJRMlzhVk1zQhrah2R4T_OiOgqoHJY0kqxLQN95Cg2yZGwgkNi1tiJhx22laLPH7K5ozOZRu3sit-jHrjZ9WKZjlVW0gpH_QLtjBRipp82sQXc-Nqln7_Qyv3pk9CsRYVkM3ICYkqJ4Z6yY7WgaZz2cEacG7NbVE9qPQ-QYpreug_HWnGaZVBV1TQyHAObBPtiW-OVQeSkUIPOevc4ZrpvFO6s4ijevKaWBU40D3mW0c_hzlj5vgn_5v1KOMs53-J3TuUl9CS0TEmLwt5ULUB_nXB7E4bqHnrWiedlNPbdfmIf5vRcVFAcXz9BIzB0V9VukgKA3tO2VCwBVf9Igy6a2mF-T7XFFAT5XjM7Gi7kXSSD74i08G5Hbd_wD4npggtRSpol_SxRPRdd7cnv__CwJMRyWkj3qQ_42bJKC2Ff_bEjNjD1ecprKVPq7J03t6wJMapnUk9BL5F-p70OF3OZLnkv7zgJUC-w8o02iezkCB4J1JRUUcn6umjscmMvWAI7BqY3H3UzHqKVr-EpADWAloLKewgzfQgTQte7NBN_CjAXFWWArwNvGLWhdau2TOXghhd_UlscebqVlZOM8NiqCW_AZxs1x1SACPLnKeAEq6jFNYwXAqAOT9qzl2pjEjf_XOXvgvNqHhnYYBexyNwzcrdik1_SatwoYTd-KTscWRoLsd84v6Y9a07SoCvauvDifR-9WjKO1921jZ5cM2T5Vsq3SmKUb3I6BCDCRPPQ8j0ZeRk5_M0zlQRbgR1OiOQkw_EfgnpuTCX4CqWKDpi0y7_UYAHAREnKX_pC6W6M68YxvqfXYjUdc3c4dLr0jGTC1Pz7uDuyfAJ_-q0pXD4H94GBc8Y5L1usoBemNDNmDps1_WnPIbrnvDPgLs_AFDyM-2VTR1Fd9m4MCvgl1OS9ZBFy99k-TMzKzcH3tJFVJ-o9bGy6Th_UxGTNuMcPd7Okv1G8t5focnNC4thkfuKb_8LOwZCkEmv5UwQy9PQ58CWAlDPpY5GFQD2T7C14N5PWhZxKPZFjwZ2BlCfb0u2EC8LvqDyhI5OMLphbo2s3wgZeEfcVqkl5anO03PS3MDEpHGX6rx1YLILwPh77qgRhBhJvSQpcZBkXJtBUkIVWdOctHmBTP1EPhR-8NOE60TFqymlfzbfd1hWXR4o0x8Ue-73vLhomP8I3l2MGyixy8aA7f37rDprwkHZq9cNyWBTaEr0O_JrBw0-Kl-BE5VE86pvVxktz7XcnRdvPg6717uqXGfUv6w4FLJWUr3wgMgxsJmqDQJ55bzd7P6cvv_1nKr3RwfCeBsuvt6zdKpOQtxOHjBZtfI5Hc4pCiscidiVwiqBDPncA3YVLyKT5LHu6hgX5Dz2xtKXPCc27B86M8uDlJpvBuupqUcq-8EV5GsMQDY3rHDiEujJcKimuyyLp72Oe740ESWljceg0U29jqIm-rijiG10POR0l6UqDENLycIvGjCDDIxuy_xtvNGnMWXn178gWrq6kInYeZYpMJ8daL88ANFStIlYcz_Ow0hMIGEaiLeL1vAiPmBAOxmnGZY2hkg-nhGKBzKpO2Butz0gY36GrpVVsyRuf1RfVvmNYS5GlIDGxm8cKyr9F78X2MZhq0aAMbLU4oEOaVAtnCh2imuYsOQ9HJGKpPmIs1yDlfjXZ5ow">
#         </form>
#     </div>
# </div>
# <script>
#     (function(){
#         window._cf_chl_opt={
#             cvId: '2',
#             cZone: 'www.indeed.com',
#             cType: 'managed',
#             cNounce: '59204',
#             cRay: '79dd58628dd5397f',
#             cHash: 'db5078c945c0403',
#             cUPMDTk: "\/jobs?q=software+developer&__cf_chl_tk=8FGiHCvh0GQzAuHTKRLfQR.eHC9WVI2ptzpHezBV5W4-1677127874-0-gaNycGzNCVA",
#             cFPWv: 'g',
#             cTTimeMs: '1000',
#             cMTimeMs: '0',
#             cTplV: 4,
#             cTplB: 'cf',
#             cRq: {
#                 ru: 'aHR0cHM6Ly93d3cuaW5kZWVkLmNvbS9qb2JzP3E9c29mdHdhcmUrZGV2ZWxvcGVy',
#                 ra: 'TW96aWxsYS81LjAgKFgxMTsgTGludXggeDg2XzY0KSBBcHBsZVdlYktpdC81MzcuMzYgKEtIVE1MLCBsaWtlIEdlY2tvKSBDaHJvbWUvNzcuMC4zODY1LjEyMCBTYWZhcmkvNTM3LjM2',
#                 rm: 'R0VU',
#                 d: '...',
#                 t: 'MTY3NzEyNzg3NC45NzUwMDA=',
#                 m: 'SJ5Syq1j2/gB/w3UYpgoad5/5f7yfR0/UieDSl5YMfo=',
#                 i1: 'uJcSFzzVJyZ8QzVPMHCTog==',
#                 i2: 'iNpM9W6g6TD6+ktx8f+ssQ==',
#                 zh: '2kfjrLYfAVNem19Lin3oP+VKo7ladb55se1eVtiLLnQ=',
#                 uh: 'Y8XdOAU1zN5Mj90pcgcwuvH3oHiZYN8bTyjSxzTIfSU=',
#                 hh: 'kscNdiThTx/CcYpUiV7EP4v/VgPxIHsoBIQQ6Rdzvmg=',
#             }
#         };
#         var trkjs = document.createElement('img');
#         trkjs.setAttribute('src', '/cdn-cgi/images/trace/managed/js/transparent.gif?ray=79dd58628dd5397f');
#         trkjs.setAttribute('alt', '');
#         trkjs.setAttribute('style', 'display: none');
#         document.body.appendChild(trkjs);
#         var cpo = document.createElement('script');
#         cpo.src = '/cdn-cgi/challenge-platform/h/g/orchestrate/managed/v1?ray=79dd58628dd5397f';
#         window._cf_chl_opt.cOgUHash = location.hash === '' && location.href.indexOf('#') !== -1 ? '#' : location.hash;
#         window._cf_chl_opt.cOgUQuery = location.search === '' && location.href.slice(0, location.href.length - window._cf_chl_opt.cOgUHash.length).indexOf('?') !== -1 ? '?' : location.search;
#         if (window.history && window.history.replaceState) {
#             var ogU = location.pathname + window._cf_chl_opt.cOgUQuery + window._cf_chl_opt.cOgUHash;
#             history.replaceState(null, null, "\/jobs?q=software+developer&__cf_chl_rt_tk=8FGiHCvh0GQzAuHTKRLfQR.eHC9WVI2ptzpHezBV5W4-1677127874-0-gaNycGzNCVA" + window._cf_chl_opt.cOgUHash);
#             cpo.onload = function() {
#                 history.replaceState(null, null, ogU);
#             };
#         }
#         document.getElementsByTagName('head')[0].appendChild(cpo);
#     }());
# </script>
#
#
#     <div class="footer" role="contentinfo">
#         <div class="footer-inner">
#             <div class="clearfix diagnostic-wrapper">
#                 <div class="ray-id">Ray ID: <code>79dd58628dd5397f</code></div>
#             </div>
#             <div class="text-center" id="footer-text">Performance &amp; security by <a rel="noopener noreferrer" href="https://www.cloudflare.com?utm_source=challenge&utm_campaign=m" target="_blank">Cloudflare</a></div>
#         </div>
#     </div>
# </body>
# </html>

# %%
url = "https://www.indeed.com/jobs?q=software+developer"

payload = ""
headers = {
  'Authorization': 'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpYXQiOjE2NzM5OTgxMTcsImV4cCI6MTY3NDAwMTcxN30.C10qRQLvWgMFOWfwrW9hECIP44LrQmOR8WzR-3ghQH4',
  'Cookie': 'CTK=1gpu892pik7i9800; __cf_bm=9Qu_iWGF_hZ6VonV17zH1yBoUukIiJq52af7QM3N10o-1677126307-0-Aahwo58ATVUH9lHIV7CJcAERJfj5QQqpUP2vi2DciCDNhS3CTpHKLD/fAD+nqOFuWsA0equKTzvgXIKYi5RZ1qk=; _cfuvid=Z.9vfYhwVv_olyH0i.YuaXeRGTMv4VpLSbCarlBL6gI-1677126307162-0-604800000; INDEED_CSRF_TOKEN=tBGpXDlM1aB4t1tgoOMDYPO4SHoCdCSA; JSESSIONID=EB076B46C74DFB4AC27A1BD433DBB939; LV="LA=1677126306:CV=1677126306:TS=1677126306"; RQ="q=software+developer&l=&ts=1677126366336"; UD="LA=1677126366:CV=1677126306:TS=1677126306:SG=945c41d3bb6cfc369fbd8e6112303114"; indeed_rcc="LV:CTK:UD"; jaSerpCount=2; loctip=1'
}

response = requests.request("GET", url, headers=headers, data=payload)
print(response)
# Out:
# <Response [403]>

# %%
# web driver setup
driver = uc.Chrome()

# %%
# get first page
driver.get('https://www.indeed.com/jobs?q=software+developer')
sleep(5)
html = driver.page_source

# %%
# Making soup
soup = BeautifulSoup(html, 'html.parser')

# %%
# Create datafram
df = pd.DataFrame()

# %%
# parent container for job cards
jobs_list=soup.find('div', attrs={'id': 'mosaic-provider-jobcards'})

# extracting data from each job card
titles = [title.text for title in jobs_list.find_all('h2', class_='jobTitle')] 
df['Job_Title'] = titles

companies = [company.text for company in jobs_list.find_all('span',class_='companyName') ]
df['Company'] = companies

links = [link['href'] for link in jobs_list.find_all('a', class_='jcs-JobTitle') ]
df['Link'] = links

# %%
# sample url to job listing 
url = 'https://indeed.com' + links[0]
print(url)
# Out:
# https://indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0C2jYUvdFqRXZP53KWtkKxs4XYthJKVjsqtZp73MH88cmtItUpXEyJRor6dU2OE0MAqhLXORpt53_IGdAYOiGDYZYhpZj4zEmRE7UVwAU7FBzidhaLA7AfpX4SCDHdPwXcMlvNapUUq7oyJHldk6eRzTmuEAcpjh1FYkH8kBqNJZWdVkFuf4SIrF8F0dKgQHVZn-kR7_l_Q3iMmKBtYX1pGGq5YcXfPJJB5qunPW8GKb54GGrtCuUi3woPabY9ku2SnYo1BdvsZuHF44HQnnwkkqvsg4PWA4Q97V1mta8htHWhBtOSVhk8LObZZGl2X7SkYpETpB8z782ACEa21XYeTbx7zNIckVbFDmWT2ugGj6n2067aJf84LIZabFLQLk94ou_njJIeypqZJ4grKXYOKcCHeJ4nLsaDCYj4auOc_tvOig9vK-J82h5CESRwTuL-Azv3HxXexW3v41ExcNhP2Bjuhzl4AjlP8fTaJUzQBNt7SE4jmA1WDsxNKFkx5Lzk7fLCgBoRD8g==&xkcb=SoDP-_M3T-aX6jQSHZ0LbzkdCdPP&p=0&fvj=1&vjs=3

# %%
df
# Out:
#                                             Job_Title  \
# 0                                  Software Developer
# 1   Scientific Instrumentation Software Developer ...
# 2          Senior Software Engineer (Remote Eligible)
# 3                       Senior Software Engineer Ruby
# 4   Senior Software Engineer - Angular/.NET (Remot...
# 5                           Junior Software Developer
# 6               Vice President - Software Development
# 7                                   Software Engineer
# 8                        Software Developer - Digital
# 9                                        UI Developer
# 10                   Software Developer - Entry Level
# 11                     Application Developer (Remote)
# 12  Entry Level Software Engineer - 2023 College Grad
# 13                                 Software Developer
# 14           Staff Software Engineer, Personalization
#
#                               Company  \
# 0                 Cheeseman Transport
# 1                              SciTec
# 2                         Capital One
# 3                               KUBRA
# 4                        Rock Central
# 5   ManTech International Corporation
# 6                               Uline
# 7                            MCKESSON
# 8                    Costco Wholesale
# 9                      Vetro Tech Inc
# 10                       Urban League
# 11  ManTech International Corporation
# 12                        BAE Systems
# 13              Reynolds and Reynolds
# 14                            Discord
#
#                                                  Link
# 0   /pagead/clk?mo=r&ad=-6NYlbfkN0C2jYUvdFqRXZP53K...
# 1   /pagead/clk?mo=r&ad=-6NYlbfkN0CdXcUcsHs_uy1jdZ...
# 2   /pagead/clk?mo=r&ad=-6NYlbfkN0C3j_zLGvpMLCdiZ0...
# 3   /pagead/clk?mo=r&ad=-6NYlbfkN0BVVjiO4Re_H6Dyxa...
# 4   /pagead/clk?mo=r&ad=-6NYlbfkN0D1gKYbjhnuLsLCCs...
# 5   /pagead/clk?mo=r&ad=-6NYlbfkN0BrkGAw7VGTTnqsFJ...
# 6   /pagead/clk?mo=r&ad=-6NYlbfkN0Ad3giXQyOqSjtuCa...
# 7   /pagead/clk?mo=r&ad=-6NYlbfkN0C6D6WZThmbXjRUxh...
# 8   /rc/clk?jk=e12f1a3d6b565ad1&fccid=9b77e2b0ccfb...
# 9   /company/Vetro-Tech-Inc/jobs/Ui-Developer-47e2...
# 10  /rc/clk?jk=a4e8260a9841531b&fccid=0366d60ddd8e...
# 11  /pagead/clk?mo=r&ad=-6NYlbfkN0BrkGAw7VGTTnqsFJ...
# 12  /pagead/clk?mo=r&ad=-6NYlbfkN0AhvKCKnyqjkpSCFI...
# 13  /rc/clk?jk=9de3d909b1137c0c&fccid=f28d659c13a0...
# 14  /rc/clk?jk=b5a31b410a037fcb&fccid=f2ab4689def1...

# %%
driver.close()

# %%
# going to each job listing to get description
descriptions = []

for link in links:
    url = 'https://indeed.com' + link
    driver.get(url)
    sleep(5)
    html = driver.page_source
    cup = BeautifulSoup(html, 'html.parser')
    description = cup.find('div', id='jobDescriptionText')
    descriptions.append(description.text)

# %%
df['Description'] = descriptions

# %%
# 
df.Link = df.Link.apply(lambda link: 'https://indeed.com' + link)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Job_Title    15 non-null     object
#  1   Company      15 non-null     object
#  2   Link         15 non-null     object
#  3   Description  15 non-null     object
# dtypes: object(4)
# memory usage: 612.0+ bytes

# %%
df
# Out:
#                                             Job_Title  \
# 0                                  Software Developer
# 1   Scientific Instrumentation Software Developer ...
# 2          Senior Software Engineer (Remote Eligible)
# 3                       Senior Software Engineer Ruby
# 4   Senior Software Engineer - Angular/.NET (Remot...
# 5                           Junior Software Developer
# 6               Vice President - Software Development
# 7                                   Software Engineer
# 8                        Software Developer - Digital
# 9                                        UI Developer
# 10                   Software Developer - Entry Level
# 11                     Application Developer (Remote)
# 12  Entry Level Software Engineer - 2023 College Grad
# 13                                 Software Developer
# 14           Staff Software Engineer, Personalization
#
#                               Company  \
# 0                 Cheeseman Transport
# 1                              SciTec
# 2                         Capital One
# 3                               KUBRA
# 4                        Rock Central
# 5   ManTech International Corporation
# 6                               Uline
# 7                            MCKESSON
# 8                    Costco Wholesale
# 9                      Vetro Tech Inc
# 10                       Urban League
# 11  ManTech International Corporation
# 12                        BAE Systems
# 13              Reynolds and Reynolds
# 14                            Discord
#
#                                                  Link  \
# 0   https://indeed.com/pagead/clk?mo=r&ad=-6NYlbfk...
# 1   https://indeed.com/pagead/clk?mo=r&ad=-6NYlbfk...
# 2   https://indeed.com/pagead/clk?mo=r&ad=-6NYlbfk...
# 3   https://indeed.com/pagead/clk?mo=r&ad=-6NYlbfk...
# 4   https://indeed.com/pagead/clk?mo=r&ad=-6NYlbfk...
# 5   https://indeed.com/pagead/clk?mo=r&ad=-6NYlbfk...
# 6   https://indeed.com/pagead/clk?mo=r&ad=-6NYlbfk...
# 7   https://indeed.com/pagead/clk?mo=r&ad=-6NYlbfk...
# 8   https://indeed.com/rc/clk?jk=e12f1a3d6b565ad1&...
# 9   https://indeed.com/company/Vetro-Tech-Inc/jobs...
# 10  https://indeed.com/rc/clk?jk=a4e8260a9841531b&...
# 11  https://indeed.com/pagead/clk?mo=r&ad=-6NYlbfk...
# 12  https://indeed.com/pagead/clk?mo=r&ad=-6NYlbfk...
# 13  https://indeed.com/rc/clk?jk=9de3d909b1137c0c&...
# 14  https://indeed.com/rc/clk?jk=b5a31b410a037fcb&...
#
#                                           Description
# 0   Cheeseman LLC, a leading transportation compan...
# 1   \nSciTec has been awarded multiple government ...
# 2   \n Locations: VA - McLean, United States of Am...
# 3   Overview\nAre you interested in joining a dyna...
# 4   \n\nAs a Rocket Companies®’ team member, you’r...
# 5   \nSecure our Nation, Ignite your Future \n\nMa...
# 6   \nVice President - Software Development\n Corp...
# 7   \nAt CoverMyMeds, we have built a nationally r...
# 8   \n\nCostco IT is responsible for the technical...
# 9   We are looking for a creative, skilled UI deve...
# 10  Urban League is looking for a passionate, expe...
# 11  \nSecure our Nation, Ignite your Future \n\nBe...
# 12  \nJob Description \n You don’t see it, but it’...
# 13  \nReynolds and Reynolds is looking for creativ...
# 14  At Discord, we believe everyone can find a pla...

# %%
# Output
df.to_csv(f'indeed_{date.today()}.csv')
df.to_json(f'indeed_{date.today()}.json')
